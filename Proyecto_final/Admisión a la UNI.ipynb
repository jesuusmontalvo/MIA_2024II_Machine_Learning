# %% [markdown]
# # Admisión a la Universidad Nacional de Ingenieria

# %% [markdown]
# ## Análisis Exploratorio
# - *Distribución de variables numéricas:*
#   - Graficar la distribución de CALIF_FINAL y correlacionarla con variables como ANIO_POSTULA o COLEGIO_ANIO_EGRESO.
#   - Ver outliers usando diagramas de caja (boxplots).
#
# - *Distribución de categorías:*
#   - Frecuencias de valores únicos en columnas categóricas como COLEGIO, ESPECIALIDAD, MODALIDAD y SEXO.
#   - Representar gráficamente estas distribuciones (gráficos de barras, pasteles).
#
# - *Análisis geográfico:*
#   - Crear un mapa con la distribución de postulantes por regiones (COLEGIO_DEPA, NACIMIENTO_DEPA, etc.).
#   - Comparar desempeño (CALIF_FINAL) por región o colegio.
#
# - *Análisis temporal:*
#   - ¿Cómo evolucionan los puntajes (CALIF_FINAL) en función del año de postulación (ANIO_POSTULA)?
#
# - *Análisis de correlación:*
#   - Identificar correlaciones entre variables numéricas usando una matriz de correlación.
#   - Pregunta inicial: ¿Existen factores que predicen un puntaje alto en CALIF_FINAL?

# %% [markdown]
# ### Objetivos:
# - *Clasificación:*
#   - ¿Qué factores predicen si un postulante ingresa (INGRESO: "SI" o "NO")?
#   - ¿Qué modalidad (MODALIDAD) es más probable para un postulante?
#
# - *Regresión:*
#   - Predecir el puntaje final (CALIF_FINAL) basado en características como COLEGIO, ESPECIALIDAD, y variables demográficas.

# %%
import pandas as pd

# %%
df = pd.read_csv("admision_uni_2021_1_2024_1.csv")

# %%
df
# Out:
#                                                   IDHASH  \
# 0      E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 1      2DC37F0B9727B6591EC72D7A942647797A200F45D47C9E...
# 2      3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 3      FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# 4      E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
# ...                                                  ...
# 42511  370728AB03E7ECDE69265AC64B0A682887B0BA3E40644F...
# 42512  C03C7AC74210DA0F4862BFEDAE45CF3BB5AE9813FCF409...
# 42513  E6337F43BAEF0F59EDF11F6F16A47A908717DE288B7886...
# 42514  13F7CD09C661B02F61218445885DA7C4FDBD87392F7522...
# 42515  89BFAB90B1C8C25D61557264958F988E305385A9351B5C...
#
#                           COLEGIO COLEGIO_DEPA           COLEGIO_PROV  \
# 0           LA DIVINA PROVIDENCIA         LIMA                   LIMA
# 1               86019 LA LIBERTAD       ÁNCASH                 HUARAZ
# ...

# %%
df.describe(include="all")
# Out:
#                                                    IDHASH            COLEGIO  \
# count                                               42516              42516
# unique                                              26177               3970
# top     8C9FB312AA48B4E42D5638C8A437E0FC26D7C470861905...  TRILCE LOS OLIVOS
# freq                                                    7                581
# mean                                                  NaN                NaN
# std                                                   NaN                NaN
# min                                                   NaN                NaN
# 25%                                                   NaN                NaN
# 50%                                                   NaN                NaN
# 75%                                                   NaN                NaN
# max                                                   NaN                NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42516 entries, 0 to 42515
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   IDHASH               42516 non-null  object
#  1   COLEGIO              42516 non-null  object
#  2   COLEGIO_DEPA         42290 non-null  object
#  3   COLEGIO_PROV         42288 non-null  object
#  4   COLEGIO_DIST         42288 non-null  object
#  5   COLEGIO_PAIS         18942 non-null  object
#  6   COLEGIO_ANIO_EGRESO  42516 non-null  int64
#  7   ESPECIALIDAD         42461 non-null  object
#  8   ANIO_POSTULA         42516 non-null  int64
#  9   CICLO_POSTULA        42516 non-null  int64
#  10  DOMICILIO_DEPA       42516 non-null  object
#  11  DOMICILIO_PROV       42516 non-null  object
#  12  DOMICILIO_DIST       42516 non-null  object
#  13  ANIO_NACIMIENTO      42516 non-null  int64
#  14  NACIMIENTO_PAIS      42516 non-null  object
# ...
